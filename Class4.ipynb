# %%
pip install pandas
# Out:
# ...
#
# ...
#      -------------------------------------- 10.6/10.6 MB 758.6 kB/s eta 0:00:00
# ...
#      ------------------------------------ 502.3/502.3 kB 700.0 kB/s eta 0:00:00
# ...
#      ------------------------------------ 341.8/341.8 kB 757.1 kB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
customers=pd.read_csv('"C:\UOFT\file\transactions.csv"')
# Out:
#   Cell In[3], line 1
#     customers=pd.read_csv('"C:\UOFT\file\transactions.csv"')
#                                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 3-4: truncated \UXXXXXXXX escape

# %%
customers=pd.read_csv("C:\UOFT\file\transactions.csv")
# Out:
#   Cell In[4], line 1
#     customers=pd.read_csv("C:\UOFT\file\transactions.csv")
#                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
customers=pd.read_csv(r"C:\UOFT\file\transactions.csv")

# %%
customers
# Out:
#     id  customer_id txn_type  txn_total
# 0    1         1001    Debit     165.78
# 1    2         1001   Credit      42.10
# 2    4         1001   Credit     103.03
# 3    5         1001   Credit      56.60
# 4    6         1002    Debit     214.34
# 5    7         1002     Cash     115.69
# 6    8         1002    Debit      21.37
# 7    9         1004     Cash     227.58
# 8   10         1004   Credit       5.92
# 9   11         1006    Debit     225.89
# 10  12         1014     Cash      67.96
# 11  13         1254    Debit     235.79
# 12  14         1285     Cash     160.89
# 13  15         1354   Credit     377.26
# 14  16         1005    Debit     276.01
# 15  17         1008   Credit     190.02
# 16  18         1585    Debit     320.40
# 17  19         1475     Cash     328.72
# 18  20         1014    Debit     449.39
# 19  21         1254     Cash      15.26
# 20  22         1285   Credit     393.91
# 21  23         1354    Debit      94.32
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           34 non-null     int64
#  1   customer_id  34 non-null     int64
#  2   txn_type     34 non-null     object
#  3   txn_total    34 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.2+ KB

# %%
customers.describe()
# Out:
#               id  customer_id   txn_total
# count  34.000000    34.000000   34.000000
# mean   18.441176  1175.411765  207.296765
# std    10.057987   211.165900  124.283187
# min     1.000000  1001.000000    5.920000
# 25%    10.250000  1004.250000  106.195000
# 50%    18.500000  1014.000000  220.115000
# 75%    26.750000  1336.750000  273.582500
# max    35.000000  1585.000000  449.390000

# %%
customers.describe(include='all')
# Out:
#                id  customer_id txn_type   txn_total
# count   34.000000    34.000000       34   34.000000
# unique        NaN          NaN        3         NaN
# top           NaN          NaN    Debit         NaN
# freq          NaN          NaN       14         NaN
# mean    18.441176  1175.411765      NaN  207.296765
# std     10.057987   211.165900      NaN  124.283187
# min      1.000000  1001.000000      NaN    5.920000
# 25%     10.250000  1004.250000      NaN  106.195000
# 50%     18.500000  1014.000000      NaN  220.115000
# 75%     26.750000  1336.750000      NaN  273.582500
# max     35.000000  1585.000000      NaN  449.390000

# %%
customers.head(6)
# Out:
#    id  customer_id txn_type  txn_total
# 0   1         1001    Debit     165.78
# 1   2         1001   Credit      42.10
# 2   4         1001   Credit     103.03
# 3   5         1001   Credit      56.60
# 4   6         1002    Debit     214.34
# 5   7         1002     Cash     115.69

# %%
customers.tail(8)
# Out:
#     id  customer_id txn_type  txn_total
# 26  28         1014     Cash     183.08
# 27  29         1254   Credit     255.21
# 28  30         1285    Debit     256.60
# 29  31         1354   Credit     438.29
# 30  32         1005    Debit     122.06
# 31  33         1008     Cash     166.44
# 32  34         1585    Debit     307.91
# 33  35         1475     Cash     266.30

# %%
customers.set_index('id')
# Out:
#     customer_id txn_type  txn_total
# id
# 1          1001    Debit     165.78
# 2          1001   Credit      42.10
# 4          1001   Credit     103.03
# 5          1001   Credit      56.60
# 6          1002    Debit     214.34
# 7          1002     Cash     115.69
# 8          1002    Debit      21.37
# 9          1004     Cash     227.58
# 10         1004   Credit       5.92
# 11         1006    Debit     225.89
# 12         1014     Cash      67.96
# 13         1254    Debit     235.79
# 14         1285     Cash     160.89
# 15         1354   Credit     377.26
# 16         1005    Debit     276.01
# 17         1008   Credit     190.02
# 18         1585    Debit     320.40
# 19         1475     Cash     328.72
# 20         1014    Debit     449.39
# 21         1254     Cash      15.26
# 22         1285   Credit     393.91
# 23         1354    Debit      94.32
# 24         1005    Debit     403.62
# 25         1008     Cash     242.73
# 26         1585     Cash     230.24
# ...

# %%
customers.set_index('id', inplace=True)

# %%
customers.loc[1004:1014]
# Out:
# Empty DataFrame
# Columns: [customer_id, txn_type, txn_total]
# Index: []

# %%
customers.loc[1004]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1004
#
# ...

# %%
customers.set_index('id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43148\1003696477.py in ?()
# ----> 1 customers.set_index('id', inplace=True)
#
# c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['id'] are in the columns"

# %%
customers
# Out:
#     customer_id txn_type  txn_total
# id
# 1          1001    Debit     165.78
# 2          1001   Credit      42.10
# 4          1001   Credit     103.03
# 5          1001   Credit      56.60
# 6          1002    Debit     214.34
# 7          1002     Cash     115.69
# 8          1002    Debit      21.37
# 9          1004     Cash     227.58
# 10         1004   Credit       5.92
# 11         1006    Debit     225.89
# 12         1014     Cash      67.96
# 13         1254    Debit     235.79
# 14         1285     Cash     160.89
# 15         1354   Credit     377.26
# 16         1005    Debit     276.01
# 17         1008   Credit     190.02
# 18         1585    Debit     320.40
# 19         1475     Cash     328.72
# 20         1014    Debit     449.39
# 21         1254     Cash      15.26
# 22         1285   Credit     393.91
# 23         1354    Debit      94.32
# 24         1005    Debit     403.62
# 25         1008     Cash     242.73
# 26         1585     Cash     230.24
# ...

# %%
customers.set_index('id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43148\4243936037.py in ?()
# ----> 1 customers.set_index('id')
#
# c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['id'] are in the columns"

# %%
customers.sort_values('len_relationship',ascending=False).head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43148\3301208843.py in ?()
# ----> 1 customers.sort_values('len_relationship',ascending=False).head(5)
#
# c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6754         elif len(by):
#    6755             # len(by) == 1
#    6756
#    6757             by = by[0]
# -> 6758             k = self._get_label_or_level_values(by, axis=axis)
#    6759
#    6760             # need to rewrap column in Series to apply key function
#    6761             if key is not None:
#
# c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
# ...

# %%
customers
# Out:
#     customer_id txn_type  txn_total
# id
# 1          1001    Debit     165.78
# 2          1001   Credit      42.10
# 4          1001   Credit     103.03
# 5          1001   Credit      56.60
# 6          1002    Debit     214.34
# 7          1002     Cash     115.69
# 8          1002    Debit      21.37
# 9          1004     Cash     227.58
# 10         1004   Credit       5.92
# 11         1006    Debit     225.89
# 12         1014     Cash      67.96
# 13         1254    Debit     235.79
# 14         1285     Cash     160.89
# 15         1354   Credit     377.26
# 16         1005    Debit     276.01
# 17         1008   Credit     190.02
# 18         1585    Debit     320.40
# 19         1475     Cash     328.72
# 20         1014    Debit     449.39
# 21         1254     Cash      15.26
# 22         1285   Credit     393.91
# 23         1354    Debit      94.32
# 24         1005    Debit     403.62
# 25         1008     Cash     242.73
# 26         1585     Cash     230.24
# ...

# %%
customers.head(6)
# Out:
#     customer_id txn_type  txn_total
# id
# 1          1001    Debit     165.78
# 2          1001   Credit      42.10
# 4          1001   Credit     103.03
# 5          1001   Credit      56.60
# 6          1002    Debit     214.34
# 7          1002     Cash     115.69

# %%
import numpy as np

# %%
customers[customers['province'] == 'ON']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'province'
#
# ...

# %%
customers_test = customers.copy()

# %%
customers[customers['province']=='ON']['num_products'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'province'
#
# ...

# %%
customers.groupby('province')[['num_products','len_relationship']].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 customers.groupby('province')[['num_products','len_relationship']].mean()
#
# File c:\Users\fishb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# ...

# %%
transactions = pd.read_csv(r"C:\UOFT\file\transactions.csv")

# %%
customers=pd.read(r"C:\UOFT\file\customers.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 customers=pd.read(r"C:\UOFT\file\customers.csv")
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
customers=pd.read_csv(r"C:\UOFT\file\customers.csv")

# %%
customers
# Out:
#       id           cust_name  num_products province  len_relationship  \
# 0   1001      Johnny Awesome             3       ON                 1
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
transactions
# Out:
#     id  customer_id txn_type  txn_total
# 0    1         1001    Debit     165.78
# 1    2         1001   Credit      42.10
# 2    4         1001   Credit     103.03
# 3    5         1001   Credit      56.60
# 4    6         1002    Debit     214.34
# 5    7         1002     Cash     115.69
# 6    8         1002    Debit      21.37
# 7    9         1004     Cash     227.58
# 8   10         1004   Credit       5.92
# 9   11         1006    Debit     225.89
# 10  12         1014     Cash      67.96
# 11  13         1254    Debit     235.79
# 12  14         1285     Cash     160.89
# 13  15         1354   Credit     377.26
# 14  16         1005    Debit     276.01
# 15  17         1008   Credit     190.02
# 16  18         1585    Debit     320.40
# 17  19         1475     Cash     328.72
# 18  20         1014    Debit     449.39
# 19  21         1254     Cash      15.26
# 20  22         1285   Credit     393.91
# 21  23         1354    Debit      94.32
# ...

# %%
joined_data.rename(columns={'id':'txn_id'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 joined_data.rename(columns={'id':'txn_id'}, inplace=True)
#
# NameError: name 'joined_data' is not defined
